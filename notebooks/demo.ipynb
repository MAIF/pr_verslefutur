# %%
import folium

# %%
m = folium.Map(location=[43.6045, 1.4442], zoom_start=12)

# %%
folium.Marker(
    [43.6045, 1.4442],
    tooltip="Toulouse"
).add_to(m)

# %%
m.save("../maps/toulouse.html")
